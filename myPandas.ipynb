# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.1.4

# %%
emptyDf = pd.DataFrame()
print(emptyDf)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
climateDf = pd.read_csv('climateData.csv')
print(climateDf)
# Out:
#     climateDate     co2  relative_temp
# 0      6/3/1958  315.71           0.10
# 1      6/4/1958  317.45           0.01
# 2      6/5/1958  317.50           0.08
# 3      6/6/1958     NaN          -0.05
# 4      6/7/1958  315.86           0.06
# ..          ...     ...            ...
# 701    6/8/2016  402.27           0.98
# 702    6/9/2016  401.05           0.87
# 703   6/10/2016  401.59           0.89
# 704   6/11/2016  403.55           0.93
# 705   6/12/2016  404.45           0.81
#
# [706 rows x 3 columns]

# %%
print(climateDf.head())
# Out:
#   climateDate     co2  relative_temp
# 0    6/3/1958  315.71           0.10
# 1    6/4/1958  317.45           0.01
# 2    6/5/1958  317.50           0.08
# 3    6/6/1958     NaN          -0.05
# 4    6/7/1958  315.86           0.06

# %%
print(climateDf.head(15))
# Out:
#    climateDate     co2  relative_temp
# 0     6/3/1958  315.71           0.10
# 1     6/4/1958  317.45           0.01
# 2     6/5/1958  317.50           0.08
# 3     6/6/1958     NaN          -0.05
# 4     6/7/1958  315.86           0.06
# 5     6/8/1958  314.93          -0.06
# 6     6/9/1958  313.20          -0.03
# 7    6/10/1958     NaN           0.04
# 8    6/11/1958  313.33           0.02
# 9    6/12/1958  314.67           0.01
# 10    6/1/1959  315.62           0.06
# 11    6/2/1959  316.38           0.09
# 12    6/3/1959  316.71           0.19
# 13    6/4/1959  317.72           0.16
# 14    6/5/1959  318.29           0.06

# %%
print(climateDf.tail())
# Out:
#     climateDate     co2  relative_temp
# 701    6/8/2016  402.27           0.98
# 702    6/9/2016  401.05           0.87
# 703   6/10/2016  401.59           0.89
# 704   6/11/2016  403.55           0.93
# 705   6/12/2016  404.45           0.81

# %%
print(climateDf.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 706 entries, 0 to 705
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   climateDate    706 non-null    object
#  1   co2            699 non-null    float64
#  2   relative_temp  706 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 16.7+ KB
# None

# %%
print(climateDf.shape)
# Out:
# (706, 3)

# %%
print(climateDf.describe())
# Out:
#               co2  relative_temp
# count  699.000000     706.000000
# mean   352.316481       0.302309
# std     26.160083       0.305417
# min    313.200000      -0.360000
# 25%    328.425000       0.050000
# 50%    350.110000       0.290000
# 75%    373.205000       0.550000
# max    407.720000       1.350000

# %%
print(climateDf.dtypes)
# Out:
# climateDate       object
# co2              float64
# relative_temp    float64
# dtype: object

# %%
print(climateDf.loc[2])
# Out:
# climateDate      6/5/1958
# co2                 317.5
# relative_temp        0.08
# Name: 2, dtype: object

# %%
removeNull = climateDf.dropna()
print(removeNull.to_string())
# Out:
#     climateDate     co2  relative_temp
# 0      6/3/1958  315.71           0.10
# 1      6/4/1958  317.45           0.01
# 2      6/5/1958  317.50           0.08
# 4      6/7/1958  315.86           0.06
# 5      6/8/1958  314.93          -0.06
# 6      6/9/1958  313.20          -0.03
# 8     6/11/1958  313.33           0.02
# 9     6/12/1958  314.67           0.01
# 10     6/1/1959  315.62           0.06
# 11     6/2/1959  316.38           0.09
# 12     6/3/1959  316.71           0.19
# 13     6/4/1959  317.72           0.16
# 14     6/5/1959  318.29           0.06
# 15     6/6/1959  318.15           0.02
# 16     6/7/1959  316.54           0.06
# 17     6/8/1959  314.80          -0.01
# 18     6/9/1959  313.84          -0.06
# 19    6/10/1959  313.26          -0.09
# 20    6/11/1959  314.80          -0.09
# 21    6/12/1959  315.58          -0.03
# 22     6/1/1960  316.43          -0.01
# 23     6/2/1960  316.97           0.14
# 24     6/3/1960  317.58          -0.36
# ...

# %%
# Change in the original one
climateDf.dropna(inplace=True)
print(climateDf.to_string())
# Out:
#     climateDate     co2  relative_temp
# 0      6/3/1958  315.71           0.10
# 1      6/4/1958  317.45           0.01
# 2      6/5/1958  317.50           0.08
# 4      6/7/1958  315.86           0.06
# 5      6/8/1958  314.93          -0.06
# 6      6/9/1958  313.20          -0.03
# 8     6/11/1958  313.33           0.02
# 9     6/12/1958  314.67           0.01
# 10     6/1/1959  315.62           0.06
# 11     6/2/1959  316.38           0.09
# 12     6/3/1959  316.71           0.19
# 13     6/4/1959  317.72           0.16
# 14     6/5/1959  318.29           0.06
# 15     6/6/1959  318.15           0.02
# 16     6/7/1959  316.54           0.06
# 17     6/8/1959  314.80          -0.01
# 18     6/9/1959  313.84          -0.06
# 19    6/10/1959  313.26          -0.09
# 20    6/11/1959  314.80          -0.09
# 21    6/12/1959  315.58          -0.03
# 22     6/1/1960  316.43          -0.01
# 23     6/2/1960  316.97           0.14
# 24     6/3/1960  317.58          -0.36
# ...

# %%
# # replace 
# climateDf['climateDate'] = climateDf.dropna(inplace=True)
# print(climateDf.to_string())
# Out:
# Empty DataFrame
# Columns: [climateDate, co2, relative_temp]
# Index: []

# %%
import datetime
climateDf['climateDate'] = pd.to_datetime(climateDf['climateDate']).dt.strftime('%Y/%m/%d')
print(climateDf.head())
# Out:
#   climateDate     co2  relative_temp
# 0  1958/06/03  315.71           0.10
# 1  1958/06/04  317.45           0.01
# 2  1958/06/05  317.50           0.08
# 3  1958/06/06     NaN          -0.05
# 4  1958/06/07  315.86           0.06

# %%
print(climateDf.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 701    False
# 702    False
# 703    False
# 704    False
# 705    False
# Length: 706, dtype: bool

# %%
climateDf.drop_duplicates(inplace=True)
print(climateDf.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 706 entries, 0 to 705
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   climateDate    706 non-null    object
#  1   co2            699 non-null    float64
#  2   relative_temp  706 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 16.7+ KB
# None
